# %%
import scipy.io

# %%
rspace_mat = scipy.io.loadmat('rspace.mat')
qspace_mat = scipy.io.loadmat('qspace.mat')

# %%
print(rspace_mat.keys())
print(qspace_mat.keys())
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'rspace'])
# dict_keys(['__header__', '__version__', '__globals__', 'qspace'])

# %%
qspace_mat['qspace'].shape
# Out:
# (33, 33, 33)

# %%
qspace_mat['qspace']
# Out:
# array([[[  38274.34124925-0.01516061j,   55371.26983085-0.01443887j,
#            93947.70807545-0.01305148j, ...,
#            93947.70808422-0.01304596j,   55371.26984378-0.01443295j,
#            38274.34126446-0.01515451j],
#         [  35223.61148947-0.0149844j ,   50957.81187143-0.01370551j,
#            86459.47530914-0.01131723j, ...,
#            86459.47559552-0.01146182j,   50957.81215584-0.01385775j,
#            35223.61177229-0.01514056j],
#         [  97123.99224711-0.02004143j,  140508.86899057-0.01781598j,
#           238399.78374724-0.01365874j, ...,
#           238399.78385372-0.01350063j,  140508.86907898-0.01766249j,
#            97123.99232576-0.01989071j],
#         ...,
#         [-100377.45831934-0.00764755j, -145215.75094778-0.00883296j,
#          -246386.06073376-0.01087957j, ...,
#          -246386.06002363-0.01082148j, -145215.75015396-0.00877118j,
#          -100377.45748179-0.00758354j],
# ...
